# %%
import sqlite3 
import pandas as pd

# %%
conn = sqlite3.connect("Extracted.db")

# %%
#Wordgraph is a subset of Graph, it only contains word -> word edges.
#While considering our sample , we are selecting only word nodes as external nodes in our metapaht
#We only use words as they contaiin inforamtion of both Lemma and CNG
df =  pd.read_sql("SELECT * FROM WordGraph", conn)
print(df.head())

# %%
df =  df.sample(n = 10000)

# %%
#Tjhis code was used on a test database, ru this on the original database on a server .
df
# Out:
#              Entity_1 Type_1         Entity_2 Type_2  Weight
# 66109         vega_89   Word        pūraka_69   Word       1
# 24413         idam_89   Word           vedi_3   Word       1
# 59907        tikta_30   Word          āmaya_3   Word       1
# 57416         tad_150   Word            ādi_3   Word       1
# 69662     vātapitta_3   Word            tad_3   Word       1
# 8839           bhū_30   Word           as_-12   Word       1
# 53542       saṃtāpa_3   Word         sev_-190   Word       1
# 28069         kara_29   Word  raktacitraka_29   Word       1
# 73552         āmaya_3   Word        saṃcāra_3   Word       1
# 61861           tā_70   Word           yad_29   Word       1
# 42873         para_30   Word      saiṃhalī_30   Word       1
# 20170         ghna_29   Word     apahāraka_29   Word       1
# 9854             ca_2   Word          anta_30   Word       1
# 68307   viṭkhadira_29   Word          hara_29   Word       1
# 56319       svarṇa_71   Word         ācar_-23   Word       1
# 9981             ca_2   Word    barhipuṣpa_29   Word       1
# 54485       snehana_3   Word          yogya_3   Word       1
# 57327         tad_149   Word          grāma_3   Word       1
# 55396      sucitrā_30   Word           as_-23   Word       1
# 28360      karañja_29   Word          nīla_29   Word       1
# 21172       grāhin_31   Word         kārin_31   Word       1
# 2552          anya_30   Word     jīrṇajvara_3   Word       1
# 28710       kaseru_30   Word        śūlikā_30   Word       1
# 79148       ṣoḍaśa_70   Word          kalā_70   Word       1
# 36186     madhyama_30   Word        dāyaka_28   Word       1
# 40893       niyama_29   Word      svastha_149   Word       1
# 34277  kṣurapattra_29   Word      bahumūla_29   Word       1
# 69830   vīrapattrī_30   Word       dhāriṇī_30   Word       1
# 5959        atisāra_3   Word          krimi_3   Word       1
# 85         abhakti_90   Word           koṭi_3   Word       1
# ...               ...    ...              ...    ...     ...
# 31332      kukkuṭī_30   Word         ākhyā_29   Word       1
# 18602     ervāruka_31   Word          mūtra_3   Word       1
# 30493  kharacchada_29   Word        ruṇḍin_29   Word       1
# 39525            na_1   Word            tva_1   Word       1
# 70204        vṛtti_40   Word           sadā_2   Word       1
# 55969     suśītala_31   Word          pitta_3   Word       1
# 51591        sahāya_3   Word       avatara_29   Word       1
# 4120     arimedaka_29   Word           śamī_3   Word       1
# 47008          prāk_2   Word          kopa_69   Word       1
# 6027       ativiṣā_30   Word         śukla_30   Word       1
# 68572        vyādhi_3   Word          ah_-153   Word       1
# 61958        tāmrā_30   Word          tathā_2   Word       1
# 1958         anitya_3   Word      anātman_181   Word       1
# 25014       ityādi_31   Word     samuccar_-23   Word       1
# 65775           vat_2   Word    aprayojaka_31   Word       1
# 28632         karṇa_3   Word           hṛt_31   Word       1
# 24837           iti_2   Word          pitta_3   Word       1
# 62127       tīkṣṇa_30   Word         hārin_30   Word       1
# 68345         vraṇa_3   Word         aśmarī_3   Word       1
# 60225       trapusī_3   Word       madhura_31   Word       1
# 42496         pac_-23   Word       kvātha_169   Word       1
# 29730          kaṭu_3   Word           hṛd_29   Word       1
# 73987        āsura_31   Word        khaṇḍa_31   Word       1
# 32572       kārikā_30   Word          kārī_30   Word       1
# 34883       lakṣmī_30   Word        subhagā_3   Word       1
# 42273    nīladūrvā_30   Word         śāntā_30   Word       1
# 23016        hetu_129   Word          niś_170   Word       1
# 78235          śīta_3   Word        svarūpa_3   Word       1
# 67917          viṣa_3   Word           han_30   Word       1
# 35180     liṅgaka_171   Word           vinā_2   Word       1
#
# [7923 rows x 5 columns]
